# %%
import importlib
import plotting as plt
import plot_functions
import numpy as np

# %%
importlib.reload(plt)
# Out:
# <module 'plotting' from '/home/mk8118/miniconda3/lib/python3.7/site-packages/mk/plotting.py'>

# %%
exp = plt.PlotLAMMPS("nvt_T0.745375_rc10.678_0.tpe")
exp.show_properties()
# Out:
# thermo_temp
# thermo_press
# thermo_press_xx
# thermo_press_yy
# thermo_press_zz
# thermo_press_xy
# thermo_press_xz
# thermo_press_yz
# surf_ten
# thermo_pe
# avg_ke

# %%
fig, ax = plot_functions.create_fig(1,1)

exp.plot_timeseries(ax[0], "surf_ten", bounds=[0, 45])
#exp.plot_mean(ax[0], "surf_ten", err=True, drift=True, bounds=[0, 45])
props, avg, err, drift = exp.get_stats(props="surf_ten")

# %%
exp.get_stats(props="surf_ten", bounds=[35, 60])
# Out:
# ('surf_ten', 81.19109485294118, 0.8975747807050544, -2.166175958889184)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-c3f65d1f2c50> in <module>
# ----> 1 stats[0][:]
#
# NameError: name 'stats' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a1b7a53d3571> in <module>
# ----> 1 [sublist[1] for sublist in stats]
#
# NameError: name 'stats' is not defined
